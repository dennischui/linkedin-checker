# %%
# !pip install requests
# Out:
# ...
#
#    ---------------------------------------- 0/3 [urllib3]
#    ---------------------------------------- 0/3 [urllib3]
#    ---------------------------------------- 0/3 [urllib3]
#    ------------- -------------------------- 1/3 [charset_normalizer]
#    ------------- -------------------------- 1/3 [charset_normalizer]
#    -------------------------- ------------- 2/3 [requests]
#    -------------------------- ------------- 2/3 [requests]
#    -------------------------- ------------- 2/3 [requests]
#    ---------------------------------------- 3/3 [requests]
#
# ...

# %%
link = "https://www.linkedin.com/jobs/view/4416727845"
link2 = "https://www.linkedin.com/jobs/view/4416763345"
import requests
result = requests.get(link)
result2 = requests.get(link2)

# %%
# get the h4 heading from the page
from bs4 import BeautifulSoup
soup = BeautifulSoup(result2.text, 'html.parser')

span1 = soup.find('span', class_='num-applicants__caption topcard__flavor--metadata topcard__flavor--bullet')
if span1 is None:
    span2 = soup.find('figcaption', class_='num-applicants__caption')

# %%
type(span1)
# Out:
# NoneType

# %%
span.text.strip()
# Out:
# 'Be among the first 25 applicants'
